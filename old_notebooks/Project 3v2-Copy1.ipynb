# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import GridSearchCV
from sklearn import linear_model
from sklearn import svm
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeClassifier
import sklearn.metrics as metrics
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix
from sklearn.metrics import precision_score, recall_score, precision_recall_curve,f1_score, fbeta_score
from sklearn.metrics import roc_auc_score, roc_curve
from sklearn.metrics import precision_recall_curve
from sklearn.tree import export_graphviz
from sklearn import tree
import graphviz 
from IPython import display
from IPython.display import Image
import pydotplus
from sklearn.dummy import DummyClassifier
from patsy import dmatrices, build_design_matrices, dmatrix
from imblearn.under_sampling import RandomUnderSampler
from collections import Counter

# %matplotlib inline
np.set_printoptions(suppress=True) # Suppress scientific notation where possible

pd.set_option('display.float_format', lambda x: '%.2f' % x)

# %% [markdown]
# step - Maps a unit of time in the real world. In this case 1 step is 1 hour of time.
# type - CASH-IN, CASH-OUT, DEBIT, PAYMENT and TRANSFER
#
# CASH-IN is the process of increasing the balance of account by paying
# in cash to a merchant.
#
# CASH-OUT is the opposite process of CASH-IN, it means to withdraw
# cash from a merchant which decreases the balance of the account.
#
# DEBIT is similar process than CASH-OUT and involves sending the
# money from the mobile money service to a bank account.
#
# PAYMENT is the process of paying for goods or services to merchants
# which decreases the balance of the account and increases the balance of
# the receiver.
#
# TRANSFER is the process of sending money to another user of the
# service through the mobile money platform.
#
# amount - amount of the transaction in local currency
#
# nameOrig - customer who started the transaction
#
# oldbalanceOrg - initial balance before the transaction
#
# newbalanceOrig - customer's balance after the transaction.
#
# nameDest - recipient ID of the transaction.
#
# oldbalanceDest - initial balance recipient before the transaction. Note that there is not information for customers that start with M (Merchants).
#
# newbalanceDest - new balance recipient after the transaction. Note that there is not information for customers that start with M (Merchants).
#
# isFraud - This is the transactions made by the fraudulent agents inside the simulation. In this specific dataset the fraudulent behavior of the agents aims to profit by taking control or customers accounts and try to empty the funds by transferring to another account and then cashing out of the system.
#
# isFlaggedFraud - The business model aims to control massive transfers from one account to another and flags illegal attempts. An illegal attempt in this dataset is an attempt to transfer more than 200.000 in a single transaction.

# %%
# Image("/Users/randy/Downloads/Screen Shot 2019-04-26 at 10.32.16 AM.png", width='200')

# %% [markdown]
# When comparing Machine Fraud to Actual Fraud:
#
# | Category | Machine  | Actual |
# | --- | --- | --- |
# | True Positive | Fraud | Fraud |
# | False Positive | Fraud | Not Fraud |
# | True Negative | Not Fraud | Not Fraud |
# | False Negative | Not Fraud | Fraud |

# %%
data = pd.read_csv('/Users/randy/Downloads/PaySim_Synthetic_Dataset-Fraud.csv')

# %%
#I want to change all of the column names to something cleaner
df = data.rename(columns = {'step':'HoursPassed',
                          'type':'TransactionType',
                          'amount':'Amount',
                          'nameOrig':'OriginatorID',
                          'oldbalanceOrg':'OldBalORIG',
                          'newbalanceOrig':'NewBalORIG', 
                          'nameDest':'RecipientID',
                          'oldbalanceDest':'OldBalRCPT', 
                          'newbalanceDest':'NewBalRCPT', 
                          'isFraud':'Fraud',
                          'isFlaggedFraud':'FlaggedFraud'
                         })

# %%
#use the pandas_profiling tool to get a summary of all the data
df.describe()

# pandas_profiling.ProfileReport(df)
# Out:
#        HoursPassed      Amount  OldBalORIG  NewBalORIG   OldBalRCPT  \
# count   6362620.00  6362620.00  6362620.00  6362620.00   6362620.00
# mean        243.40   179861.90   833883.10   855113.67   1100701.67
# std         142.33   603858.23  2888242.67  2924048.50   3399180.11
# min           1.00        0.00        0.00        0.00         0.00
# 25%         156.00    13389.57        0.00        0.00         0.00
# 50%         239.00    74871.94    14208.00        0.00    132705.66
# 75%         335.00   208721.48   107315.18   144258.41    943036.71
# max         743.00 92445516.64 59585040.37 49585040.37 356015889.35
#
#         NewBalRCPT      Fraud  FlaggedFraud
# count   6362620.00 6362620.00    6362620.00
# mean    1224996.40       0.00          0.00
# std     3674128.94       0.04          0.00
# min           0.00       0.00          0.00
# 25%           0.00       0.00          0.00
# 50%      214661.44       0.00          0.00
# 75%     1111909.25       0.00          0.00
# max   356179278.92       1.00          1.00

# %%
# df[(df.values  == 'C1669947858')]
df.tail()
# df = df[df["TransactionType"].str.contains('CASH_OUT','TRANSFER') == False]
# Out:
#          HoursPassed TransactionType     Amount OriginatorID  OldBalORIG  \
# 6362615          743        CASH_OUT  339682.13   C786484425   339682.13
# 6362616          743        TRANSFER 6311409.28  C1529008245  6311409.28
# 6362617          743        CASH_OUT 6311409.28  C1162922333  6311409.28
# 6362618          743        TRANSFER  850002.52  C1685995037   850002.52
# 6362619          743        CASH_OUT  850002.52  C1280323807   850002.52
#
#          NewBalORIG  RecipientID  OldBalRCPT  NewBalRCPT  Fraud  FlaggedFraud
# 6362615        0.00   C776919290        0.00   339682.13      1             0
# 6362616        0.00  C1881841831        0.00        0.00      1             0
# 6362617        0.00  C1365125890    68488.84  6379898.11      1             0
# 6362618        0.00  C2080388513        0.00        0.00      1             0
# 6362619        0.00   C873221189  6510099.11  7360101.63      1             0

# %% [markdown]
# # Initial Findings and Thoughts:
#
# - Transfers and Cash_Out are related in many transactions. Ex. fraudsters transfer funds then cash out fast.
# - In the IDs, C = Customer, M = Merchant
#     - There are no Originator IDs that match Recipient IDs
#     - Maybe do one-hot-encoding for C and M
# - Do one-hot-encoding for Transaction Type (drop_first = True)
# - One-hot-encoding (pd.get_dummies(my_series, drop_first=True)
# - Feature engineering - add ratio of transaction amount to old bal
#     - Ex. (ORIG) Old Bal > New Bal = negative delta
#     - Ex. (RCPT) Old Bal < New Bal = positive delta
#
# - Given that our data is extremely one-sided (imbalanced classification problem) The metric our intuition tells us we should maximize is known in statistics as recall, or the ability of a model to find all the relevant cases within a dataset.
#     - Not Fraud represents the overwhelming majority of the data points
#     - I could have an extremely high accuracy by just saying "all are not fraud" but the recall would be terrible.

# %%
#no matching Originator IDs to the Recipient IDs. I assumed this means the originator is not 
df['OriginatorID'].equals(df['RecipientID'])
# Out:
# False

# %%
#create dummies for transaction types
df_trans = pd.get_dummies(df['TransactionType'],drop_first=True)
df1 = df
frames = [df1,df_trans]
result = pd.concat(frames,axis=1)

#drop the original transaction types
result = result.drop(columns=['TransactionType'])

# %%
#remove all numbers in Originator ID and Recipient ID
result['OriginatorID'] = result['OriginatorID'].str.replace('\d+', '')
result['RecipientID'] = result['RecipientID'].str.replace('\d+', '')

#removing all the numbers in Originator ID leaves only 'C' so I drop the whole column
result = result.drop(columns = ['OriginatorID'])

#do a get_dummies for Recipient ID since there are Merchants ('M') and Customers ('C')
result_recip = pd.get_dummies(result['RecipientID'],drop_first=True)
result1 = result
frames = [result1,result_recip]
new_result = pd.concat(frames,axis=1)

new_result = new_result.drop(columns = ['RecipientID'])

# %%
result_df = new_result.drop_duplicates(['Amount'],keep='last')

# %%
#create new columns for difference in Originator ID and Recipient ID
result_df.insert(2, 'ChangeORIG', (result_df['NewBalORIG']-result_df['OldBalORIG']))
result_df.insert(4, 'ChangeRCPT', (result_df['NewBalRCPT']-result_df['OldBalRCPT']))

#drop original ORIG and RCPT transactions
final_result = result_df.drop(columns = ['OldBalORIG','NewBalORIG','OldBalRCPT','NewBalRCPT','Amount'])
#,'TRANSFER','M','PAYMENT','HoursPassed', 'FlaggedFraud'

# %%
columns = [#'HoursPassed',
           'ChangeORIG',
           'ChangeRCPT',
#            'PAYMENT',
#            'CASH_OUT', #remove this for a 0.98 RF
#            'DEBIT',
#            'TRANSFER',
#           'FlaggedFraud',
           'M'
          ]



mega_result = final_result.drop(columns=columns)

# %%
#ok, all of the variables are now either binary or some other numerical value
# new_result.info()
# # new_result_tail.describe()
mega_result['isFraud'] = final_result['Fraud']
mega_result = mega_result.drop(columns = ['Fraud'])

# %%
# data.info()
#EDA and Baselining
target_pcts = mega_result.isFraud.value_counts(normalize=False) 
print('ratio of Fraud to NotFraud: ', 8213/6354407)
print(target_pcts)

target_pcts.plot(kind='bar', color='blue');
# Out:
# ratio of Fraud to NotFraud:  0.0012924888191769902
# 0    5313063
# 1       3837
# Name: isFraud, dtype: int64

# %%
fig, ax = plt.subplots(figsize=(15,15))
sns.heatmap(mega_result.corr(), cmap="seismic", ax=ax, annot=True, vmin = -1, vmax = 1)
plt.show()

# %%
no_fraud_result = mega_result.drop(columns=['isFraud'])

# %%
X_break, X_test, y_break, y_test = train_test_split(no_fraud_result, mega_result['isFraud'], \
                                                    test_size=0.2, stratify=mega_result['isFraud'],
                                                    random_state=12345)
#random_state generates a set kind of deck for each random state. 41 will always be the same kind of split

X_train, X_val, y_train, y_val = train_test_split(X_break, y_break, \
                                                    test_size=0.25, stratify=y_break,
                                                    random_state=12345)

# %%
# X_train

# %%
# Normalize my variables
scaler = StandardScaler()
scaler.fit(X_train)
X_train_SVC = scaler.transform(X_train)
X_val_SVC = scaler.transform(X_val)
# Out:
# /Users/randy/anaconda3/lib/python3.7/site-packages/sklearn/preprocessing/data.py:645: DataConversionWarning: Data with input dtype uint8, int64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /Users/randy/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: DataConversionWarning: Data with input dtype uint8, int64 were all converted to float64 by StandardScaler.
#   after removing the cwd from sys.path.
# /Users/randy/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DataConversionWarning: Data with input dtype uint8, int64 were all converted to float64 by StandardScaler.
#   """

# %% [markdown]
# # This is where it changes. I now downsample for easier computing.

# %%
X_train_under, y_train_under = RandomUnderSampler(random_state=42).fit_sample(X_train,y_train)
X_val_under, y_val_under = RandomUnderSampler(random_state=42).fit_sample(X_val,y_val)
X_train_under_SVC, y_train_under_SVC = RandomUnderSampler(random_state=42).fit_sample(X_train_SVC,y_train)

# %%
Counter(y_train_under) #check to see that the samples are the same size
# Out:
# Counter({0: 2303, 1: 2303})

# %%
# Run CV with 5 folds (knn)

ks = [1,5,10]
param_grid = [{'n_neighbors': ks}]

knn = KNeighborsClassifier()
knn_grid = GridSearchCV(knn, param_grid, cv=5, scoring='roc_auc', verbose=30, n_jobs=-1)
knn_grid.fit(X_train_under, y_train_under)
# Out:
# Fitting 5 folds for each of 3 candidates, totalling 15 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=-1)]: Done   2 out of  15 | elapsed:    1.3s remaining:    8.5s
# [Parallel(n_jobs=-1)]: Done   3 out of  15 | elapsed:    1.3s remaining:    5.3s
# [Parallel(n_jobs=-1)]: Done   4 out of  15 | elapsed:    1.3s remaining:    3.7s
# [Parallel(n_jobs=-1)]: Done   5 out of  15 | elapsed:    1.4s remaining:    2.7s
# [Parallel(n_jobs=-1)]: Done   6 out of  15 | elapsed:    1.4s remaining:    2.0s
# [Parallel(n_jobs=-1)]: Done   7 out of  15 | elapsed:    1.4s remaining:    1.5s
# [Parallel(n_jobs=-1)]: Done   8 out of  15 | elapsed:    1.4s remaining:    1.2s
# [Parallel(n_jobs=-1)]: Done   9 out of  15 | elapsed:    1.4s remaining:    0.9s
# [Parallel(n_jobs=-1)]: Done  10 out of  15 | elapsed:    1.4s remaining:    0.7s
# [Parallel(n_jobs=-1)]: Done  11 out of  15 | elapsed:    1.4s remaining:    0.5s
# [Parallel(n_jobs=-1)]: Done  12 out of  15 | elapsed:    1.4s remaining:    0.4s
# [Parallel(n_jobs=-1)]: Done  13 out of  15 | elapsed:    1.4s remaining:    0.2s
# [Parallel(n_jobs=-1)]: Done  15 out of  15 | elapsed:    1.4s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  15 out of  15 | elapsed:    1.4s finished
# GridSearchCV(cv=5, error_score='raise-deprecating',
#        estimator=KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform'),
#        fit_params=None, iid='warn', n_jobs=-1,
#        param_grid=[{'n_neighbors': [1, 5, 10]}], pre_dispatch='2*n_jobs',
#        refit=True, return_train_score='warn', scoring='roc_auc',
#        verbose=30)

# %% [markdown]
# True Positive - marked as fraud, is fraud
# False Positive - marked as fraud, is legit
# True Negative - marked as legit, is legit
# False Negative - marked as legit, is fraud

# %%
fraud_only = result_df[result_df['Fraud'] == 1]

# %%
#loss per missed fraud (recall is much more valuable)
loss_per_fraud = round(np.mean(fraud_only['Amount']))

# %%
loss_per_fraud
# Out:
# 1204813

# %%
#we're going to assume this is 
#transactions per consumer 
transaction_per_consumer = round(np.mean(result_df['Amount']))

# %%
transaction_per_consumer
# Out:
# 202228

# %%
def make_confusion_matrix(model, threshold=0.5):
    plt.rcParams.update({'font.size': 10})
    # Predict class 1 if probability of being in class 1 is greater than threshold
    # (model.predict(X_test) does this automatically with a threshold of 0.5)
    y_predict = (model.predict_proba(X_val_under)[:, 1] >= threshold)
    fraud_confusion = confusion_matrix(y_val_under, y_predict)
    plt.figure(dpi=200)
    sns.heatmap(fraud_confusion, cmap=plt.cm.Blues, annot=True, square=True, fmt='d',
           xticklabels=['Not Fraud', 'Fraud'],
  
           yticklabels=['Not Fraud', 'Fraud']);
    TP = fraud_confusion[0][0]
    FP = fraud_confusion[0][1]
    FN = fraud_confusion[1][0]
    TN = fraud_confusion[1][1]
    plt.yticks(rotation = 0)
    print('Cost of a legitimate transaction marked as fraud (False Positive) : $', FP*transaction_per_consumer)
    print('')
    print('Cost of fraud marked as a legitimate transaction (False Negative) : $', FN*transaction_per_consumer)
    plt.title('Predicted vs. Actual',fontname = '.SF Compact Display',fontsize = 25,pad = 10);
    plt.xlabel('Predicted')
    plt.ylabel('Actual',rotation = 0)
#     plt.rcParams.update({'font.size': 20})

# %%
logit = LogisticRegression(C = 0.95)
logit.fit(X_train, y_train)
print("The score for logistic regression is")
print("Training set: {:6.2f}%".format(100*logit.score(X_train, y_train)))
print("Validation set: {:6.2f}%".format(100*logit.score(X_val, y_val)))
# Out:
# /Users/randy/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# The score for logistic regression is
# Training set:  99.93%
# Validation set:  99.93%

# %%
from ipywidgets import interactive, FloatSlider

interactive(lambda threshold: make_confusion_matrix(CV_rfc, threshold), threshold=(0.0,1.0,0.02))
# Out:
# interactive(children=(FloatSlider(value=0.5, description='threshold', max=1.0, step=0.02), Output()), _dom_cla…

# %%
# using the new threshold of n
def check_threshold(n):
    y_predict = (logit.predict_proba(X_val_under)[:,1] > float(n))
    print(f'Threshold of {n}:')
    print('Precision: {:6.4f},   Recall: {:6.4f}'.format(precision_score(y_val_under, y_predict), 
                                                     recall_score(y_val_under, y_predict)))
    print(f'Total Score: {precision_score(y_val_under, y_predict) + recall_score(y_val_under, y_predict)}')
    print('')

# %%
# using the default threshold of 0.5, which is what vanilla predict does
y_predict = logit.predict(X_val_under)
print("Default threshold: 0.5")
print("Precision: {:6.4f},   Recall: {:6.4f}".format(precision_score(y_val_under, y_predict), 
                                                     recall_score(y_val_under, y_predict)))
# Out:
# Default threshold: 0.5
# Precision: 0.0000,   Recall: 0.0000
# /Users/randy/anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
for item in np.arange(0.0, 1.0, 0.02):
    check_threshold(item)
# Out:
# Threshold of 0.0:
# Precision: 0.5000,   Recall: 1.0000
# Total Score: 1.5
#
# Threshold of 0.02:
# Precision: 0.0000,   Recall: 0.0000
# Total Score: 0.0
#
# Threshold of 0.04:
# Precision: 0.0000,   Recall: 0.0000
# Total Score: 0.0
#
# Threshold of 0.06:
# Precision: 0.0000,   Recall: 0.0000
# Total Score: 0.0
#
# Threshold of 0.08:
# Precision: 0.0000,   Recall: 0.0000
# Total Score: 0.0
#
# Threshold of 0.1:
# Precision: 0.0000,   Recall: 0.0000
# Total Score: 0.0
#
# Threshold of 0.12:
# Precision: 0.0000,   Recall: 0.0000
# Total Score: 0.0
#
# Threshold of 0.14:
# Precision: 0.0000,   Recall: 0.0000
# Total Score: 0.0
#
# Threshold of 0.16:
# Precision: 0.0000,   Recall: 0.0000
# Total Score: 0.0
#
# Threshold of 0.18:
# Precision: 0.0000,   Recall: 0.0000
# Total Score: 0.0
#
# Threshold of 0.2:
# Precision: 0.0000,   Recall: 0.0000
# Total Score: 0.0
#
# Threshold of 0.22:
# Precision: 0.0000,   Recall: 0.0000
# Total Score: 0.0
#
# Threshold of 0.24:
# Precision: 0.0000,   Recall: 0.0000
# Total Score: 0.0
#
# Threshold of 0.26:
# Precision: 0.0000,   Recall: 0.0000
# Total Score: 0.0
#
# Threshold of 0.28:
# Precision: 0.0000,   Recall: 0.0000
# Total Score: 0.0
#
# Threshold of 0.3:
# Precision: 0.0000,   Recall: 0.0000
# Total Score: 0.0
#
# Threshold of 0.32:
# Precision: 0.0000,   Recall: 0.0000
# Total Score: 0.0
#
# Threshold of 0.34:
# Precision: 0.0000,   Recall: 0.0000
# Total Score: 0.0
#
# Threshold of 0.36:
# Precision: 0.0000,   Recall: 0.0000
# Total Score: 0.0
#
# Threshold of 0.38:
# Precision: 0.0000,   Recall: 0.0000
# Total Score: 0.0
#
# Threshold of 0.4:
# Precision: 0.0000,   Recall: 0.0000
# Total Score: 0.0
#
# Threshold of 0.42:
# Precision: 0.0000,   Recall: 0.0000
# Total Score: 0.0
#
# Threshold of 0.44:
# Precision: 0.0000,   Recall: 0.0000
# Total Score: 0.0
#
# Threshold of 0.46:
# Precision: 0.0000,   Recall: 0.0000
# Total Score: 0.0
#
# Threshold of 0.48:
# Precision: 0.0000,   Recall: 0.0000
# Total Score: 0.0
#
# Threshold of 0.5:
# Precision: 0.0000,   Recall: 0.0000
# Total Score: 0.0
#
# Threshold of 0.52:
# Precision: 0.0000,   Recall: 0.0000
# Total Score: 0.0
#
# Threshold of 0.54:
# Precision: 0.0000,   Recall: 0.0000
# Total Score: 0.0
#
# Threshold of 0.56:
# Precision: 0.0000,   Recall: 0.0000
# Total Score: 0.0
#
# Threshold of 0.58:
# Precision: 0.0000,   Recall: 0.0000
# Total Score: 0.0
#
# Threshold of 0.6:
# Precision: 0.0000,   Recall: 0.0000
# Total Score: 0.0
#
# Threshold of 0.62:
# Precision: 0.0000,   Recall: 0.0000
# Total Score: 0.0
#
# Threshold of 0.64:
# Precision: 0.0000,   Recall: 0.0000
# Total Score: 0.0
#
# Threshold of 0.66:
# Precision: 0.0000,   Recall: 0.0000
# Total Score: 0.0
#
# Threshold of 0.68:
# Precision: 0.0000,   Recall: 0.0000
# Total Score: 0.0
#
# Threshold of 0.7000000000000001:
# Precision: 0.0000,   Recall: 0.0000
# Total Score: 0.0
#
# Threshold of 0.72:
# Precision: 0.0000,   Recall: 0.0000
# Total Score: 0.0
#
# Threshold of 0.74:
# Precision: 0.0000,   Recall: 0.0000
# Total Score: 0.0
#
# Threshold of 0.76:
# Precision: 0.0000,   Recall: 0.0000
# Total Score: 0.0
#
# Threshold of 0.78:
# Precision: 0.0000,   Recall: 0.0000
# Total Score: 0.0
#
# Threshold of 0.8:
# Precision: 0.0000,   Recall: 0.0000
# Total Score: 0.0
#
# Threshold of 0.8200000000000001:
# Precision: 0.0000,   Recall: 0.0000
# Total Score: 0.0
#
# Threshold of 0.84:
# Precision: 0.0000,   Recall: 0.0000
# Total Score: 0.0
#
# Threshold of 0.86:
# Precision: 0.0000,   Recall: 0.0000
# Total Score: 0.0
#
# Threshold of 0.88:
# Precision: 0.0000,   Recall: 0.0000
# Total Score: 0.0
#
# Threshold of 0.9:
# Precision: 0.0000,   Recall: 0.0000
# Total Score: 0.0
#
# Threshold of 0.92:
# Precision: 0.0000,   Recall: 0.0000
# Total Score: 0.0
#
# Threshold of 0.9400000000000001:
# Precision: 0.0000,   Recall: 0.0000
# Total Score: 0.0
#
# Threshold of 0.96:
# Precision: 0.0000,   Recall: 0.0000
# Total Score: 0.0
#
# Threshold of 0.98:
# Precision: 0.0000,   Recall: 0.0000
# Total Score: 0.0
# /Users/randy/anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/randy/anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/randy/anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/randy/anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/randy/anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/randy/anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/randy/anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/randy/anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/randy/anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/randy/anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/randy/anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/randy/anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/randy/anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/randy/anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/randy/anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/randy/anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/randy/anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/randy/anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/randy/anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/randy/anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/randy/anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/randy/anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/randy/anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/randy/anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/randy/anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/randy/anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/randy/anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/randy/anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/randy/anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/randy/anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/randy/anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/randy/anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/randy/anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/randy/anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/randy/anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/randy/anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/randy/anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/randy/anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/randy/anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/randy/anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/randy/anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/randy/anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/randy/anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/randy/anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/randy/anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/randy/anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/randy/anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/randy/anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/randy/anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/randy/anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/randy/anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/randy/anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/randy/anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/randy/anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/randy/anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/randy/anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/randy/anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/randy/anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/randy/anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/randy/anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/randy/anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/randy/anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/randy/anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/randy/anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/randy/anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/randy/anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/randy/anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/randy/anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/randy/anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/randy/anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/randy/anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/randy/anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/randy/anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/randy/anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/randy/anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/randy/anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/randy/anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/randy/anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/randy/anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/randy/anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/randy/anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/randy/anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/randy/anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/randy/anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/randy/anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/randy/anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/randy/anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/randy/anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/randy/anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/randy/anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/randy/anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/randy/anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/randy/anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/randy/anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/randy/anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/randy/anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/randy/anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/randy/anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
# We can also use the probabilities to make a curve showing us how recall 
# and thresholds trade off 

precision_curve, recall_curve, threshold_curve = precision_recall_curve(y_val_under, logit.predict_proba(X_val_under)[:,1] )

plt.figure(dpi=80)
plt.plot(threshold_curve, precision_curve[1:],label='precision')
plt.plot(threshold_curve, recall_curve[1:], label='recall')
plt.legend(loc='lower left')
plt.xlabel('Threshold (above this probability, label as fraud)');
plt.title('Precision and Recall Curves');

# %%
plt.figure(dpi=80)
plt.plot(recall_curve[1:], precision_curve[1:],label='precision')
plt.xlabel("Recall")
plt.ylabel("Precision")
plt.title("Precision-Recall Curve");

# %% [markdown]
# # The ROC Curve

# %%
# Precision = TP / (TP + FP)
# Recall = TP/P = True positive rate
# false positive rate = FP / true negatives = FP / (FP + TN)

# %%
# Run CV with 5 folds (logit)

penalty = ['l2']
C = np.logspace(0, 4, 10)
param_grid = dict(C=C, penalty=penalty)

logistic = linear_model.LogisticRegression(solver='lbfgs', max_iter=10000)
logistic_grid = GridSearchCV(logistic, param_grid, cv=5, scoring='roc_auc', verbose=30, n_jobs=-1)
logistic_grid.fit(X_train_under, y_train_under)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.0886s.) Setting batch_size=4.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-1)]: Done   5 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-1)]: Done   6 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-1)]: Done   7 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-1)]: Done   8 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-1)]: Done   9 out of  50 | elapsed:    0.1s remaining:    0.6s
# [Parallel(n_jobs=-1)]: Done  11 out of  50 | elapsed:    0.2s remaining:    0.5s
# [Parallel(n_jobs=-1)]: Done  13 out of  50 | elapsed:    0.2s remaining:    0.5s
# [Parallel(n_jobs=-1)]: Done  15 out of  50 | elapsed:    0.2s remaining:    0.4s
# [Parallel(n_jobs=-1)]: Done  17 out of  50 | elapsed:    0.2s remaining:    0.4s
# [Parallel(n_jobs=-1)]: Done  19 out of  50 | elapsed:    0.2s remaining:    0.3s
# [Parallel(n_jobs=-1)]: Done  21 out of  50 | elapsed:    0.2s remaining:    0.3s
# [Parallel(n_jobs=-1)]: Done  23 out of  50 | elapsed:    0.2s remaining:    0.3s
# [Parallel(n_jobs=-1)]: Done  50 out of  50 | elapsed:    0.4s finished
# GridSearchCV(cv=5, error_score='raise-deprecating',
#        estimator=LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=10000, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='lbfgs',
#           tol=0.0001, verbose=0, warm_start=False),
#        fit_params=None, iid='warn', n_jobs=-1,
#        param_grid={'C': array([    1.     ,     2.78256,     7.74264,    21.54435,    59.94843,
#          166.81005,   464.15888,  1291.54967,  3593.81366, 10000.     ]), 'penalty': ['l2']},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring='roc_auc', verbose=30)

# %%
# # Run CV with 5 folds (SVM). Unsure if I can run this given how long it takes

C = [1,2,5,10]
gammas = [0.001, 0.1]
param_grid = dict(C=C, gamma=gammas)

svm1 = svm.SVC(kernel='rbf', probability=True)
svm_grid = GridSearchCV(svm1, param_grid, cv=5, scoring='roc_auc', verbose=30, n_jobs=-1)
svm_grid.fit(X_train_under, y_train_under)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# Fitting 5 folds for each of 8 candidates, totalling 40 fits
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    2.6s
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    2.7s
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    2.7s
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    2.7s
# [Parallel(n_jobs=-1)]: Done   5 tasks      | elapsed:    2.7s
# [Parallel(n_jobs=-1)]: Done   6 tasks      | elapsed:    3.0s
# [Parallel(n_jobs=-1)]: Done   7 tasks      | elapsed:    3.2s
# [Parallel(n_jobs=-1)]: Done   8 tasks      | elapsed:    3.2s
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    3.3s
# [Parallel(n_jobs=-1)]: Done  10 tasks      | elapsed:    3.3s
# [Parallel(n_jobs=-1)]: Done  11 tasks      | elapsed:    3.3s
# [Parallel(n_jobs=-1)]: Done  12 tasks      | elapsed:    3.3s
# [Parallel(n_jobs=-1)]: Done  13 tasks      | elapsed:    5.3s
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:    5.4s
# [Parallel(n_jobs=-1)]: Done  15 tasks      | elapsed:    5.6s
# [Parallel(n_jobs=-1)]: Done  16 tasks      | elapsed:    5.9s
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:    5.9s
# [Parallel(n_jobs=-1)]: Done  19 out of  40 | elapsed:    6.0s remaining:    6.7s
# [Parallel(n_jobs=-1)]: Done  21 out of  40 | elapsed:    7.0s remaining:    6.3s
# [Parallel(n_jobs=-1)]: Done  23 out of  40 | elapsed:    7.1s remaining:    5.2s
# [Parallel(n_jobs=-1)]: Done  25 out of  40 | elapsed:    8.5s remaining:    5.1s
# [Parallel(n_jobs=-1)]: Done  27 out of  40 | elapsed:    8.8s remaining:    4.2s
# [Parallel(n_jobs=-1)]: Done  29 out of  40 | elapsed:    8.8s remaining:    3.4s
# [Parallel(n_jobs=-1)]: Done  31 out of  40 | elapsed:    9.8s remaining:    2.8s
# [Parallel(n_jobs=-1)]: Done  33 out of  40 | elapsed:   10.1s remaining:    2.1s
# [Parallel(n_jobs=-1)]: Done  35 out of  40 | elapsed:   10.4s remaining:    1.5s
# [Parallel(n_jobs=-1)]: Done  37 out of  40 | elapsed:   10.9s remaining:    0.9s
# [Parallel(n_jobs=-1)]: Done  40 out of  40 | elapsed:   11.0s finished
# GridSearchCV(cv=5, error_score='raise-deprecating',
#        estimator=SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=True, random_state=None,
#   shrinking=True, tol=0.001, verbose=False),
#        fit_params=None, iid='warn', n_jobs=-1,
#        param_grid={'C': [1, 2, 5, 10], 'gamma': [0.001, 0.1]},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring='roc_auc', verbose=30)

# %%
# Run CV with 5 folds (Random Forest)

# Number of trees in random forest
n_estimators = [100,250,500]#[200, 250] #200 or 250 models. test this more
# Number of features to consider at every split
max_features = ['auto'] #sqrt
# Maximum number of levels in tree
max_depth = [40,80,200]#[70, 80]
# Minimum number of samples required to split a node
min_samples_split = [5,10]#[2, 5, 10]
# Minimum number of samples required at each leaf node
min_samples_leaf = [2,4]#[1, 2, 4]
# Method of selecting samples for training each tree
bootstrap = [True]

# Create the parameter grid based on the results of random search 
param_grid = {
    'n_estimators': n_estimators,
    'max_features': max_features,
    'max_depth': max_depth, #how deep the tree gets to go, test this more
    'min_samples_split': min_samples_split,
    'min_samples_leaf': min_samples_leaf,
    'bootstrap': bootstrap
}

# # Use the random grid to search for best hyperparameters
# # First create the base model to tune
# rf = RandomForestRegressor()
# # Random search of parameters, using 3 fold cross validation, 
# # search across 100 different combinations, and use all available cores
# rf_random = RandomizedSearchCV(estimator = rf, param_distributions = random_grid, n_iter = 100, cv = 3, verbose=10, random_state=42, n_jobs = -1)
# # Fit the random search model
# rf_random.fit(X_train, y_train)

# #looking for the best hyperparams
# #Create base model to tune
rfc=RandomForestClassifier()

CV_rfc = GridSearchCV(estimator=rfc, param_grid=param_grid, cv=5, verbose=30, n_jobs=-1)
CV_rfc.fit(X_train_under, y_train_under)
# Out:
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done   5 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done   6 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done   7 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done   8 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=-1)]: Done  10 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=-1)]: Done  11 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=-1)]: Done  12 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=-1)]: Done  13 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=-1)]: Done  15 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=-1)]: Done  16 tasks      | elapsed:    2.0s
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:    2.0s
# [Parallel(n_jobs=-1)]: Done  18 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=-1)]: Done  19 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=-1)]: Done  20 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=-1)]: Done  22 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=-1)]: Done  23 tasks      | elapsed:    2.5s
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:    2.5s
# [Parallel(n_jobs=-1)]: Done  25 tasks      | elapsed:    2.5s
# [Parallel(n_jobs=-1)]: Done  26 tasks      | elapsed:    2.5s
# [Parallel(n_jobs=-1)]: Done  27 tasks      | elapsed:    2.6s
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:    2.6s
# [Parallel(n_jobs=-1)]: Done  29 tasks      | elapsed:    2.7s
# [Parallel(n_jobs=-1)]: Done  30 tasks      | elapsed:    2.9s
# [Parallel(n_jobs=-1)]: Done  31 tasks      | elapsed:    3.4s
# [Parallel(n_jobs=-1)]: Done  32 tasks      | elapsed:    3.5s
# [Parallel(n_jobs=-1)]: Done  33 tasks      | elapsed:    3.5s
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    3.5s
# [Parallel(n_jobs=-1)]: Done  35 tasks      | elapsed:    3.6s
# [Parallel(n_jobs=-1)]: Done  36 tasks      | elapsed:    3.6s
# [Parallel(n_jobs=-1)]: Done  37 tasks      | elapsed:    3.6s
# [Parallel(n_jobs=-1)]: Done  38 tasks      | elapsed:    3.9s
# [Parallel(n_jobs=-1)]: Done  39 tasks      | elapsed:    3.9s
# [Parallel(n_jobs=-1)]: Done  40 tasks      | elapsed:    4.0s
# [Parallel(n_jobs=-1)]: Done  41 tasks      | elapsed:    4.0s
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:    4.1s
# [Parallel(n_jobs=-1)]: Done  43 tasks      | elapsed:    4.1s
# [Parallel(n_jobs=-1)]: Done  44 tasks      | elapsed:    4.2s
# [Parallel(n_jobs=-1)]: Done  45 tasks      | elapsed:    4.3s
# [Parallel(n_jobs=-1)]: Done  46 tasks      | elapsed:    4.6s
# [Parallel(n_jobs=-1)]: Done  47 tasks      | elapsed:    4.8s
# [Parallel(n_jobs=-1)]: Done  48 tasks      | elapsed:    4.9s
# [Parallel(n_jobs=-1)]: Done  49 tasks      | elapsed:    5.0s
# [Parallel(n_jobs=-1)]: Done  50 tasks      | elapsed:    5.0s
# [Parallel(n_jobs=-1)]: Done  51 tasks      | elapsed:    5.0s
# [Parallel(n_jobs=-1)]: Done  52 tasks      | elapsed:    5.1s
# [Parallel(n_jobs=-1)]: Done  53 tasks      | elapsed:    5.3s
# [Parallel(n_jobs=-1)]: Done  54 tasks      | elapsed:    5.4s
# [Parallel(n_jobs=-1)]: Done  55 tasks      | elapsed:    5.4s
# [Parallel(n_jobs=-1)]: Done  56 tasks      | elapsed:    5.4s
# [Parallel(n_jobs=-1)]: Done  57 tasks      | elapsed:    5.4s
# [Parallel(n_jobs=-1)]: Done  58 tasks      | elapsed:    5.5s
# [Parallel(n_jobs=-1)]: Done  59 tasks      | elapsed:    5.5s
# [Parallel(n_jobs=-1)]: Done  60 tasks      | elapsed:    5.7s
# [Parallel(n_jobs=-1)]: Done  61 tasks      | elapsed:    6.1s
# [Parallel(n_jobs=-1)]: Done  62 tasks      | elapsed:    6.2s
# [Parallel(n_jobs=-1)]: Done  63 tasks      | elapsed:    6.3s
# [Parallel(n_jobs=-1)]: Done  64 tasks      | elapsed:    6.4s
# [Parallel(n_jobs=-1)]: Done  65 tasks      | elapsed:    6.4s
# [Parallel(n_jobs=-1)]: Done  66 tasks      | elapsed:    6.4s
# [Parallel(n_jobs=-1)]: Done  67 tasks      | elapsed:    6.5s
# [Parallel(n_jobs=-1)]: Done  68 tasks      | elapsed:    6.6s
# [Parallel(n_jobs=-1)]: Done  69 tasks      | elapsed:    6.8s
# [Parallel(n_jobs=-1)]: Done  70 tasks      | elapsed:    6.8s
# [Parallel(n_jobs=-1)]: Done  71 tasks      | elapsed:    6.8s
# [Parallel(n_jobs=-1)]: Done  72 tasks      | elapsed:    6.8s
# [Parallel(n_jobs=-1)]: Done  73 tasks      | elapsed:    6.8s
# [Parallel(n_jobs=-1)]: Done  74 tasks      | elapsed:    6.9s
# [Parallel(n_jobs=-1)]: Done  75 tasks      | elapsed:    7.0s
# [Parallel(n_jobs=-1)]: Done  76 tasks      | elapsed:    7.4s
# [Parallel(n_jobs=-1)]: Done  77 tasks      | elapsed:    7.7s
# [Parallel(n_jobs=-1)]: Done  78 tasks      | elapsed:    7.7s
# [Parallel(n_jobs=-1)]: Done  79 tasks      | elapsed:    7.8s
# [Parallel(n_jobs=-1)]: Done  80 tasks      | elapsed:    7.8s
# [Parallel(n_jobs=-1)]: Done  81 tasks      | elapsed:    7.8s
# [Parallel(n_jobs=-1)]: Done  82 tasks      | elapsed:    7.8s
# [Parallel(n_jobs=-1)]: Done  83 tasks      | elapsed:    8.1s
# [Parallel(n_jobs=-1)]: Done  84 tasks      | elapsed:    8.1s
# [Parallel(n_jobs=-1)]: Done  85 tasks      | elapsed:    8.2s
# [Parallel(n_jobs=-1)]: Done  86 tasks      | elapsed:    8.2s
# [Parallel(n_jobs=-1)]: Done  87 tasks      | elapsed:    8.2s
# [Parallel(n_jobs=-1)]: Done  88 tasks      | elapsed:    8.2s
# [Parallel(n_jobs=-1)]: Done  89 tasks      | elapsed:    8.3s
# [Parallel(n_jobs=-1)]: Done  90 tasks      | elapsed:    8.5s
# [Parallel(n_jobs=-1)]: Done  91 tasks      | elapsed:    8.8s
# [Parallel(n_jobs=-1)]: Done  92 tasks      | elapsed:    8.9s
# [Parallel(n_jobs=-1)]: Done  93 tasks      | elapsed:    9.1s
# [Parallel(n_jobs=-1)]: Done  94 tasks      | elapsed:    9.3s
# [Parallel(n_jobs=-1)]: Done  95 tasks      | elapsed:    9.3s
# [Parallel(n_jobs=-1)]: Done  96 tasks      | elapsed:    9.3s
# [Parallel(n_jobs=-1)]: Done  97 tasks      | elapsed:    9.3s
# [Parallel(n_jobs=-1)]: Done  98 tasks      | elapsed:    9.6s
# [Parallel(n_jobs=-1)]: Done  99 tasks      | elapsed:    9.8s
# [Parallel(n_jobs=-1)]: Done 100 tasks      | elapsed:    9.8s
# [Parallel(n_jobs=-1)]: Done 101 tasks      | elapsed:    9.8s
# [Parallel(n_jobs=-1)]: Done 102 tasks      | elapsed:    9.8s
# [Parallel(n_jobs=-1)]: Done 103 tasks      | elapsed:    9.9s
# [Parallel(n_jobs=-1)]: Done 104 tasks      | elapsed:   10.0s
# [Parallel(n_jobs=-1)]: Done 105 tasks      | elapsed:   10.1s
# [Parallel(n_jobs=-1)]: Done 106 tasks      | elapsed:   10.6s
# [Parallel(n_jobs=-1)]: Done 107 tasks      | elapsed:   10.8s
# [Parallel(n_jobs=-1)]: Done 108 tasks      | elapsed:   10.9s
# [Parallel(n_jobs=-1)]: Done 109 tasks      | elapsed:   10.9s
# [Parallel(n_jobs=-1)]: Done 110 tasks      | elapsed:   10.9s
# [Parallel(n_jobs=-1)]: Done 111 tasks      | elapsed:   11.0s
# [Parallel(n_jobs=-1)]: Done 112 tasks      | elapsed:   11.0s
# [Parallel(n_jobs=-1)]: Done 113 tasks      | elapsed:   11.3s
# [Parallel(n_jobs=-1)]: Done 114 tasks      | elapsed:   11.4s
# [Parallel(n_jobs=-1)]: Done 115 tasks      | elapsed:   11.4s
# [Parallel(n_jobs=-1)]: Done 116 tasks      | elapsed:   11.4s
# [Parallel(n_jobs=-1)]: Done 117 tasks      | elapsed:   11.5s
# [Parallel(n_jobs=-1)]: Done 118 tasks      | elapsed:   11.5s
# [Parallel(n_jobs=-1)]: Done 119 tasks      | elapsed:   11.5s
# [Parallel(n_jobs=-1)]: Done 120 tasks      | elapsed:   11.8s
# [Parallel(n_jobs=-1)]: Done 121 tasks      | elapsed:   12.2s
# [Parallel(n_jobs=-1)]: Done 122 tasks      | elapsed:   12.3s
# [Parallel(n_jobs=-1)]: Done 123 tasks      | elapsed:   12.5s
# [Parallel(n_jobs=-1)]: Done 124 tasks      | elapsed:   12.5s
# [Parallel(n_jobs=-1)]: Done 125 tasks      | elapsed:   12.6s
# [Parallel(n_jobs=-1)]: Done 126 tasks      | elapsed:   12.6s
# [Parallel(n_jobs=-1)]: Done 127 tasks      | elapsed:   12.6s
# [Parallel(n_jobs=-1)]: Done 128 tasks      | elapsed:   12.8s
# [Parallel(n_jobs=-1)]: Done 129 tasks      | elapsed:   13.0s
# [Parallel(n_jobs=-1)]: Done 130 tasks      | elapsed:   13.0s
# [Parallel(n_jobs=-1)]: Done 131 tasks      | elapsed:   13.0s
# [Parallel(n_jobs=-1)]: Done 132 tasks      | elapsed:   13.1s
# [Parallel(n_jobs=-1)]: Done 133 tasks      | elapsed:   13.1s
# [Parallel(n_jobs=-1)]: Done 134 tasks      | elapsed:   13.1s
# [Parallel(n_jobs=-1)]: Done 135 tasks      | elapsed:   13.3s
# [Parallel(n_jobs=-1)]: Done 136 tasks      | elapsed:   13.8s
# [Parallel(n_jobs=-1)]: Done 137 tasks      | elapsed:   14.0s
# [Parallel(n_jobs=-1)]: Done 138 tasks      | elapsed:   14.1s
# [Parallel(n_jobs=-1)]: Done 139 tasks      | elapsed:   14.1s
# [Parallel(n_jobs=-1)]: Done 140 tasks      | elapsed:   14.1s
# [Parallel(n_jobs=-1)]: Done 141 tasks      | elapsed:   14.2s
# [Parallel(n_jobs=-1)]: Done 142 tasks      | elapsed:   14.2s
# [Parallel(n_jobs=-1)]: Done 143 tasks      | elapsed:   14.4s
# [Parallel(n_jobs=-1)]: Done 144 tasks      | elapsed:   14.5s
# [Parallel(n_jobs=-1)]: Done 145 tasks      | elapsed:   14.5s
# [Parallel(n_jobs=-1)]: Done 146 tasks      | elapsed:   14.5s
# [Parallel(n_jobs=-1)]: Done 147 tasks      | elapsed:   14.6s
# [Parallel(n_jobs=-1)]: Done 148 tasks      | elapsed:   14.7s
# [Parallel(n_jobs=-1)]: Done 149 tasks      | elapsed:   14.8s
# [Parallel(n_jobs=-1)]: Done 150 tasks      | elapsed:   14.9s
# [Parallel(n_jobs=-1)]: Done 151 tasks      | elapsed:   15.3s
# [Parallel(n_jobs=-1)]: Done 152 tasks      | elapsed:   15.4s
# [Parallel(n_jobs=-1)]: Done 153 tasks      | elapsed:   15.6s
# [Parallel(n_jobs=-1)]: Done 154 tasks      | elapsed:   15.7s
# [Parallel(n_jobs=-1)]: Done 155 tasks      | elapsed:   15.7s
# [Parallel(n_jobs=-1)]: Done 156 tasks      | elapsed:   15.7s
# [Parallel(n_jobs=-1)]: Done 157 tasks      | elapsed:   15.8s
# [Parallel(n_jobs=-1)]: Done 164 out of 180 | elapsed:   16.3s remaining:    1.6s
# [Parallel(n_jobs=-1)]: Done 171 out of 180 | elapsed:   17.5s remaining:    0.9s
# [Parallel(n_jobs=-1)]: Done 178 out of 180 | elapsed:   18.6s remaining:    0.2s
# [Parallel(n_jobs=-1)]: Done 180 out of 180 | elapsed:   18.7s finished
# GridSearchCV(cv=5, error_score='raise-deprecating',
#        estimator=RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators='warn', n_jobs=None,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False),
#        fit_params=None, iid='warn', n_jobs=-1,
#        param_grid={'n_estimators': [100, 250, 500], 'max_features': ['auto'], 'max_depth': [40, 80, 200], 'min_samples_split': [5, 10], 'min_samples_leaf': [2, 4], 'bootstrap': [True]},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring=None, verbose=30)

# %%
# Fit a Naive Bayes Model

gnb = GaussianNB()
gnb_best = gnb.fit(X_train_under, y_train_under)

# %%
# # Fit sub_grade Classifier

# isFraud = 'isFraud'
# x_patsy_sg = dmatrix(isFraud, X_train)
#x_patsy_sg_test = x_patsy_sg[test_index,:]
# x_patsy_sg_val = x_patsy_sg[y_val,:]
# x_patsy_sg_train = x_patsy_sg[y_train,:]

# logistic_sub_grade = linear_model.LogisticRegression(solver='lbfgs', max_iter=10000)
# logistic_sub_grade.fit(x_patsy_sg_train, y_train)
# logistic_sub_grade.coef_

# %%
print('Best ROC_AUC for logit: %0.4f' % logistic_grid.best_score_)
print('Best ROC_AUC for svm: %0.4f' % svm_grid.best_score_)
print('Best ROC_AUC for rf: %0.4f' % CV_rfc.best_score_)
# Out:
# Best ROC_AUC for logit: 0.8778
# Best ROC_AUC for svm: 0.9158
# Best ROC_AUC for rf: 0.8495

# %%
print('Best Params for logit: ', logistic_grid.best_params_)
print('Best Params for svm: ', svm_grid.best_params_)
print('Best Params for rf: ', CV_rfc.best_params_)
# Out:
# Best Params for logit:  {'C': 59.94842503189409, 'penalty': 'l2'}
# Best Params for svm:  {'C': 5, 'gamma': 0.1}
# Best Params for rf:  {'bootstrap': True, 'max_depth': 40, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 5, 'n_estimators': 250}

# %%
dc = DummyClassifier()
dc.fit(X_train_under, y_train_under)
# print("Log-loss on dummy classifier: {:6.4f}".format(log_loss(y_val, dc.predict_proba(X_val))))
# Out:
# DummyClassifier(constant=None, random_state=None, strategy='stratified')

# %%
# final_result.loc[final_result['isFraud'] == 1].mean()

# %%
#in sample
plt.rcParams.update({'font.size': 30})
model_list = [logistic_grid.best_estimator_, 
#              svm_grid.best_estimator_, 
              gnb_best,
#               rf_random.best_estimator_,
#              knn_grid.best_estimator_,
              CV_rfc.best_estimator_,
#              dc
             ]

model_name = ['Logit','Naive Bayes', 'Random Forest']#,'KNN' 'SVM',,'Dummy'
 
# Plot ROC curve for all my models
fig, ax = plt.subplots(figsize=(20,18))
for i, model in enumerate(model_list):
    y_pred = list(model.predict_proba(X_val_under)[:,1])
    fpr, tpr, threshold = metrics.roc_curve(y_val_under, y_pred)
    roc_auc = metrics.auc(fpr, tpr)
    plt.plot(fpr, tpr, label = (model_name[i] + ' AUC = %0.4f' % roc_auc),linewidth=2.0)
ax.grid(False)
ax.tick_params(length=6, width=2,labelsize = 20,
               grid_color='r', grid_alpha=0.5)
# plt.legend(loc = 'lower right',prop={'size': 25})
leg = plt.legend(loc = 'lower right',prop={'size': 25})
leg.get_frame().set_edgecolor('b')
plt.title('Receiver Operating Characteristic (ROC)', FontSize=40)
plt.plot([0, 1], [0, 1], 'r--')
plt.xlim([-.02, 1.02])
plt.ylim([-.02, 1.02])
plt.ylabel('True Positive Rate',FontSize=30)
plt.xlabel('False Positive Rate',FontSize=30)
plt.show()

# %%
#out of sample
plt.rcParams.update({'font.size': 20})
model_list = [logistic_grid.best_estimator_, 
#              svm_grid.best_estimator_, 
              gnb_best,
#               rf_random.best_estimator_,
#               knn_grid.best_estimator_,
              CV_rfc.best_estimator_,
             dc]

model_name = ['Logit','Naive Bayes', 'Random Forest','Dummy']#,'KNN' 'SVM',
 
# Plot ROC curve for all my models
fig, ax = plt.subplots(figsize=(20,18))
for i, model in enumerate(model_list):
    y_pred = list(model.predict_proba(X_test)[:,1])
    fpr, tpr, threshold = metrics.roc_curve(y_test, y_pred)
    roc_auc = metrics.auc(fpr, tpr)
    plt.plot(fpr, tpr, label = (model_name[i] + ' AUC = %0.4f' % roc_auc),linewidth=2.0)

plt.legend(loc = 'lower right',prop={'size': 25})
plt.title('Receiver Operating Characteristic (ROC)', FontSize=40)
plt.plot([0, 1], [0, 1], 'r--')
plt.xlim([-.02, 1.02])
plt.ylim([-.02, 1.02])
plt.ylabel('True Positive Rate', FontSize=30)
plt.xlabel('False Positive Rate', FontSize=30)
plt.show()

# %%
for item1,item2 in zip(X_test.columns,CV_rfc.best_estimator_.feature_importances_):
    print(f'{item1} has a score of {item2}')
# Out:
# HoursPassed has a score of 0.471699381067303
# FlaggedFraud has a score of 0.00442785909589384
# CASH_OUT has a score of 0.41236573893265743
# DEBIT has a score of 0.0008494693633096843
# PAYMENT has a score of 0.09069628901097947
# TRANSFER has a score of 0.01996126252985669

# %% [markdown]
# # Finding the F1 score and Threshold

# %%
from sklearn.neural_network import MLPClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier

model_dict = {'rfc': RandomForestClassifier(n_estimators = 400, n_jobs = -1,max_features = 'sqrt'),
             'lm' : LogisticRegression(max_iter =10000,solver='sag',verbose = 10,n_jobs = -1),
             'gnb' : GaussianNB(),
             'mlp' : MLPClassifier(verbose = 10),
             'gbc' : GradientBoostingClassifier(n_estimators =  1000, max_leaf_nodes = 4,\
                                                max_depth = None ,min_samples_split = 5, verbose = 10,
                                               learning_rate = .1)}

# %%
def make_model(mdl_key,X_train,y_train,X_test):
    """Uses key from model_dict and trains it on X_train, y_train, then returns \
    the model object used and predicted values on X_test"""
    assert (mdl_key in model_dict.keys()),"Model tag not in model_dict keys!"
    mdl = model_dict[mdl_key]
    mdl.fit(X_train,y_train)
    predicted = mdl.predict(X_test)
    return mdl, predicted

# %%
rfc, gnb_predicted = make_model('rfc',X_train_under,y_train_under,X_val_under)

# %%
lm, predicted = make_model('lm',X_train_under,y_train_under,X_val_under)
# Out:
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 12 concurrent workers.
# convergence after 3440 epochs took 3 seconds
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    3.0s
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    3.0s finished

# %%
gnb, gnb_predicted = make_model('gnb',X_train_under,y_train_under,X_val_under)

# %%
mlp, mlp_predicted = make_model('mlp',X_train_under,y_train_under,X_val_under)
# Out:
# Iteration 1, loss = 3.24271507
# Iteration 2, loss = 0.80543630
# Iteration 3, loss = 0.66699482
# Iteration 4, loss = 0.64743825
# Iteration 5, loss = 0.63060321
# Iteration 6, loss = 0.61914189
# Iteration 7, loss = 0.63176506
# Iteration 8, loss = 0.59905240
# Iteration 9, loss = 0.57532001
# Iteration 10, loss = 0.57911097
# Iteration 11, loss = 0.56900447
# Iteration 12, loss = 0.53878138
# Iteration 13, loss = 0.54392348
# Iteration 14, loss = 0.53731369
# Iteration 15, loss = 0.51164976
# Iteration 16, loss = 0.52098504
# Iteration 17, loss = 0.49226857
# Iteration 18, loss = 0.48970494
# Iteration 19, loss = 0.47765754
# Iteration 20, loss = 0.47193793
# Iteration 21, loss = 0.46770227
# Iteration 22, loss = 0.46972905
# Iteration 23, loss = 0.45911293
# Iteration 24, loss = 0.46476529
# Iteration 25, loss = 0.45238986
# Iteration 26, loss = 0.47958526
# Iteration 27, loss = 0.45022673
# Iteration 28, loss = 0.44128953
# Iteration 29, loss = 0.44601794
# Iteration 30, loss = 0.44551204
# Iteration 31, loss = 0.44912270
# Iteration 32, loss = 0.44485433
# Iteration 33, loss = 0.43921162
# Iteration 34, loss = 0.45361494
# Iteration 35, loss = 0.52968200
# Iteration 36, loss = 0.43153065
# Iteration 37, loss = 0.45415427
# Iteration 38, loss = 0.43025216
# Iteration 39, loss = 0.42604728
# Iteration 40, loss = 0.42505155
# Iteration 41, loss = 0.53023218
# Iteration 42, loss = 0.44040901
# Iteration 43, loss = 0.41910752
# Iteration 44, loss = 0.41973837
# Iteration 45, loss = 0.41522908
# Iteration 46, loss = 0.45871237
# Iteration 47, loss = 0.44566472
# Iteration 48, loss = 0.43246544
# Iteration 49, loss = 0.45651580
# Iteration 50, loss = 0.45064122
# Iteration 51, loss = 0.42740300
# Iteration 52, loss = 0.42711831
# Iteration 53, loss = 0.40949522
# Iteration 54, loss = 0.40896220
# Iteration 55, loss = 0.41606631
# Iteration 56, loss = 0.42464280
# Iteration 57, loss = 0.41296126
# Iteration 58, loss = 0.40900269
# Iteration 59, loss = 0.41936438
# Iteration 60, loss = 0.41798144
# Iteration 61, loss = 0.44607148
# Iteration 62, loss = 0.44265860
# Iteration 63, loss = 0.41283836
# Iteration 64, loss = 0.40403263
# Iteration 65, loss = 0.40315945
# Iteration 66, loss = 0.40096955
# Iteration 67, loss = 0.46617703
# Iteration 68, loss = 0.41538326
# Iteration 69, loss = 0.41162425
# Iteration 70, loss = 0.47677983
# Iteration 71, loss = 0.41834034
# Iteration 72, loss = 0.40632744
# Iteration 73, loss = 0.41039476
# Iteration 74, loss = 0.42681042
# Iteration 75, loss = 0.39773585
# Iteration 76, loss = 0.40071486
# Iteration 77, loss = 0.40358452
# Iteration 78, loss = 0.51593915
# Iteration 79, loss = 0.47891764
# Iteration 80, loss = 0.45027305
# Iteration 81, loss = 0.40125804
# Iteration 82, loss = 0.42334105
# Iteration 83, loss = 0.40507260
# Iteration 84, loss = 0.39897566
# Iteration 85, loss = 0.40312031
# Iteration 86, loss = 0.40510681
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.

# %%
gbc, gbc_predicted = make_model('gbc',X_train_under,y_train_under,X_val_under)
# Out:
#       Iter       Train Loss   Remaining Time
#          1           1.2837            2.31s
#          2           1.1999            1.99s
#          3           1.1302            1.89s
#          4           1.0716            1.87s
#          5           1.0217            1.77s
#          6           0.9789            1.74s
#          7           0.9420            1.70s
#          8           0.9100            1.71s
#          9           0.8822            1.71s
#         10           0.8578            1.68s
#         11           0.8362            1.63s
#         12           0.8174            1.61s
#         13           0.8007            1.58s
#         14           0.7854            1.55s
#         15           0.7716            1.53s
#         16           0.7594            1.51s
#         17           0.7483            1.50s
#         18           0.7387            1.49s
#         19           0.7296            1.48s
#         20           0.7214            1.47s
#         21           0.7141            1.48s
#         22           0.7073            1.49s
#         23           0.7026            1.48s
#         24           0.6969            1.49s
#         25           0.6922            1.48s
#         26           0.6874            1.48s
#         27           0.6838            1.48s
#         28           0.6798            1.47s
#         29           0.6767            1.48s
#         30           0.6733            1.48s
#         31           0.6701            1.47s
#         32           0.6685            1.47s
#         33           0.6660            1.46s
#         34           0.6636            1.45s
#         35           0.6615            1.44s
#         36           0.6601            1.44s
#         37           0.6582            1.43s
#         38           0.6557            1.43s
#         39           0.6541            1.43s
#         40           0.6519            1.42s
#         41           0.6502            1.42s
#         42           0.6492            1.41s
#         43           0.6473            1.40s
#         44           0.6460            1.40s
#         45           0.6445            1.40s
#         46           0.6425            1.40s
#         47           0.6413            1.39s
#         48           0.6400            1.39s
#         49           0.6383            1.38s
#         50           0.6368            1.38s
#         51           0.6361            1.38s
#         52           0.6342            1.39s
#         53           0.6337            1.39s
#         54           0.6324            1.39s
#         55           0.6310            1.39s
#         56           0.6300            1.40s
#         57           0.6289            1.40s
#         58           0.6279            1.41s
#         59           0.6267            1.41s
#         60           0.6251            1.41s
#         61           0.6243            1.41s
#         62           0.6236            1.41s
#         63           0.6229            1.41s
#         64           0.6213            1.41s
#         65           0.6202            1.40s
#         66           0.6191            1.39s
#         67           0.6184            1.39s
#         68           0.6173            1.39s
#         69           0.6160            1.39s
#         70           0.6146            1.39s
#         71           0.6134            1.38s
#         72           0.6125            1.38s
#         73           0.6122            1.38s
#         74           0.6114            1.38s
#         75           0.6107            1.38s
#         76           0.6096            1.38s
#         77           0.6089            1.38s
#         78           0.6081            1.38s
#         79           0.6060            1.38s
#         80           0.6051            1.37s
#         81           0.6041            1.37s
#         82           0.6035            1.36s
#         83           0.6018            1.36s
#         84           0.6013            1.36s
#         85           0.6003            1.36s
#         86           0.5996            1.35s
#         87           0.5984            1.35s
#         88           0.5980            1.35s
#         89           0.5973            1.34s
#         90           0.5965            1.34s
#         91           0.5957            1.34s
#         92           0.5955            1.33s
#         93           0.5945            1.33s
#         94           0.5935            1.33s
#         95           0.5929            1.32s
#         96           0.5919            1.32s
#         97           0.5912            1.32s
#         98           0.5902            1.32s
#         99           0.5887            1.32s
#        100           0.5874            1.32s
#        101           0.5867            1.32s
#        102           0.5863            1.32s
#        103           0.5858            1.31s
#        104           0.5853            1.31s
#        105           0.5844            1.31s
#        106           0.5838            1.31s
#        107           0.5833            1.30s
#        108           0.5824            1.30s
#        109           0.5817            1.30s
#        110           0.5812            1.30s
#        111           0.5811            1.30s
#        112           0.5800            1.30s
#        113           0.5795            1.30s
#        114           0.5786            1.30s
#        115           0.5781            1.29s
#        116           0.5771            1.29s
#        117           0.5765            1.29s
#        118           0.5764            1.28s
#        119           0.5760            1.28s
#        120           0.5757            1.28s
#        121           0.5752            1.28s
#        122           0.5748            1.27s
#        123           0.5738            1.27s
#        124           0.5725            1.27s
#        125           0.5713            1.27s
#        126           0.5705            1.27s
#        127           0.5697            1.28s
#        128           0.5689            1.27s
#        129           0.5680            1.28s
#        130           0.5671            1.28s
#        131           0.5664            1.28s
#        132           0.5661            1.27s
#        133           0.5654            1.27s
#        134           0.5650            1.27s
#        135           0.5644            1.27s
#        136           0.5635            1.27s
#        137           0.5630            1.27s
#        138           0.5622            1.27s
#        139           0.5614            1.27s
#        140           0.5606            1.27s
#        141           0.5595            1.27s
#        142           0.5592            1.26s
#        143           0.5587            1.26s
#        144           0.5582            1.26s
#        145           0.5579            1.26s
#        146           0.5577            1.26s
#        147           0.5573            1.26s
#        148           0.5568            1.26s
#        149           0.5562            1.26s
#        150           0.5558            1.26s
#        151           0.5553            1.25s
#        152           0.5551            1.25s
#        153           0.5544            1.25s
#        154           0.5536            1.25s
#        155           0.5529            1.25s
#        156           0.5526            1.25s
#        157           0.5519            1.25s
#        158           0.5513            1.25s
#        159           0.5507            1.25s
#        160           0.5504            1.25s
#        161           0.5503            1.24s
#        162           0.5500            1.24s
#        163           0.5495            1.24s
#        164           0.5489            1.24s
#        165           0.5484            1.24s
#        166           0.5476            1.24s
#        167           0.5471            1.24s
#        168           0.5468            1.24s
#        169           0.5462            1.24s
#        170           0.5457            1.23s
#        171           0.5453            1.23s
#        172           0.5448            1.23s
#        173           0.5443            1.23s
#        174           0.5443            1.23s
#        175           0.5442            1.23s
#        176           0.5439            1.23s
#        177           0.5437            1.23s
#        178           0.5432            1.22s
#        179           0.5428            1.22s
#        180           0.5425            1.22s
#        181           0.5423            1.22s
#        182           0.5418            1.22s
#        183           0.5416            1.22s
#        184           0.5412            1.22s
#        185           0.5410            1.22s
#        186           0.5405            1.22s
#        187           0.5399            1.22s
#        188           0.5395            1.22s
#        189           0.5387            1.22s
#        190           0.5380            1.22s
#        191           0.5374            1.22s
#        192           0.5365            1.22s
#        193           0.5359            1.22s
#        194           0.5357            1.22s
#        195           0.5354            1.22s
#        196           0.5350            1.22s
#        197           0.5347            1.22s
#        198           0.5341            1.22s
#        199           0.5334            1.22s
#        200           0.5331            1.22s
#        201           0.5331            1.21s
#        202           0.5328            1.21s
#        203           0.5325            1.21s
#        204           0.5323            1.21s
#        205           0.5320            1.21s
#        206           0.5315            1.21s
#        207           0.5314            1.21s
#        208           0.5311            1.21s
#        209           0.5310            1.21s
#        210           0.5300            1.20s
#        211           0.5298            1.20s
#        212           0.5296            1.20s
#        213           0.5292            1.20s
#        214           0.5292            1.20s
#        215           0.5288            1.19s
#        216           0.5281            1.19s
#        217           0.5275            1.19s
#        218           0.5270            1.19s
#        219           0.5266            1.19s
#        220           0.5260            1.19s
#        221           0.5255            1.19s
#        222           0.5251            1.19s
#        223           0.5249            1.18s
#        224           0.5247            1.18s
#        225           0.5246            1.18s
#        226           0.5241            1.18s
#        227           0.5235            1.17s
#        228           0.5231            1.17s
#        229           0.5227            1.17s
#        230           0.5226            1.17s
#        231           0.5224            1.17s
#        232           0.5217            1.17s
#        233           0.5214            1.16s
#        234           0.5213            1.16s
#        235           0.5212            1.16s
#        236           0.5209            1.16s
#        237           0.5207            1.16s
#        238           0.5207            1.15s
#        239           0.5205            1.15s
#        240           0.5202            1.15s
#        241           0.5196            1.15s
#        242           0.5192            1.15s
#        243           0.5186            1.15s
#        244           0.5183            1.15s
#        245           0.5178            1.15s
#        246           0.5175            1.14s
#        247           0.5173            1.14s
#        248           0.5170            1.14s
#        249           0.5168            1.14s
#        250           0.5163            1.14s
#        251           0.5158            1.14s
#        252           0.5156            1.13s
#        253           0.5151            1.13s
#        254           0.5148            1.13s
#        255           0.5145            1.13s
#        256           0.5140            1.13s
#        257           0.5136            1.13s
#        258           0.5132            1.12s
#        259           0.5128            1.12s
#        260           0.5124            1.12s
#        261           0.5123            1.12s
#        262           0.5120            1.11s
#        263           0.5119            1.11s
#        264           0.5119            1.11s
#        265           0.5116            1.11s
#        266           0.5113            1.10s
#        267           0.5111            1.10s
#        268           0.5107            1.10s
#        269           0.5103            1.10s
#        270           0.5101            1.09s
#        271           0.5097            1.09s
#        272           0.5093            1.09s
#        273           0.5089            1.09s
#        274           0.5087            1.09s
#        275           0.5085            1.08s
#        276           0.5084            1.08s
#        277           0.5083            1.08s
#        278           0.5082            1.08s
#        279           0.5079            1.07s
#        280           0.5078            1.07s
#        281           0.5077            1.07s
#        282           0.5073            1.07s
#        283           0.5069            1.07s
#        284           0.5068            1.06s
#        285           0.5065            1.06s
#        286           0.5063            1.06s
#        287           0.5058            1.06s
#        288           0.5055            1.06s
#        289           0.5054            1.06s
#        290           0.5053            1.06s
#        291           0.5051            1.06s
#        292           0.5050            1.05s
#        293           0.5049            1.05s
#        294           0.5048            1.05s
#        295           0.5045            1.05s
#        296           0.5043            1.05s
#        297           0.5039            1.05s
#        298           0.5035            1.05s
#        299           0.5032            1.04s
#        300           0.5027            1.04s
#        301           0.5024            1.04s
#        302           0.5022            1.04s
#        303           0.5021            1.04s
#        304           0.5019            1.04s
#        305           0.5018            1.04s
#        306           0.5016            1.03s
#        307           0.5015            1.03s
#        308           0.5014            1.03s
#        309           0.5012            1.03s
#        310           0.5010            1.03s
#        311           0.5006            1.03s
#        312           0.5003            1.03s
#        313           0.5000            1.02s
#        314           0.4999            1.02s
#        315           0.4990            1.02s
#        316           0.4988            1.02s
#        317           0.4987            1.02s
#        318           0.4986            1.02s
#        319           0.4982            1.01s
#        320           0.4981            1.01s
#        321           0.4978            1.01s
#        322           0.4976            1.01s
#        323           0.4975            1.01s
#        324           0.4973            1.01s
#        325           0.4971            1.00s
#        326           0.4970            1.00s
#        327           0.4969            1.00s
#        328           0.4964            1.00s
#        329           0.4963            1.00s
#        330           0.4962            0.99s
#        331           0.4959            0.99s
#        332           0.4957            0.99s
#        333           0.4955            0.99s
#        334           0.4954            0.99s
#        335           0.4952            0.99s
#        336           0.4950            0.98s
#        337           0.4949            0.98s
#        338           0.4947            0.98s
#        339           0.4947            0.98s
#        340           0.4944            0.97s
#        341           0.4940            0.97s
#        342           0.4939            0.97s
#        343           0.4937            0.97s
#        344           0.4933            0.97s
#        345           0.4930            0.96s
#        346           0.4930            0.96s
#        347           0.4928            0.96s
#        348           0.4927            0.96s
#        349           0.4925            0.96s
#        350           0.4922            0.95s
#        351           0.4919            0.95s
#        352           0.4918            0.95s
#        353           0.4917            0.95s
#        354           0.4916            0.95s
#        355           0.4915            0.94s
#        356           0.4914            0.94s
#        357           0.4913            0.94s
#        358           0.4912            0.94s
#        359           0.4911            0.93s
#        360           0.4910            0.93s
#        361           0.4909            0.93s
#        362           0.4906            0.93s
#        363           0.4905            0.93s
#        364           0.4904            0.92s
#        365           0.4903            0.92s
#        366           0.4901            0.92s
#        367           0.4899            0.92s
#        368           0.4897            0.92s
#        369           0.4894            0.91s
#        370           0.4891            0.91s
#        371           0.4888            0.91s
#        372           0.4888            0.91s
#        373           0.4887            0.91s
#        374           0.4885            0.91s
#        375           0.4882            0.91s
#        376           0.4881            0.90s
#        377           0.4878            0.90s
#        378           0.4877            0.90s
#        379           0.4875            0.90s
#        380           0.4872            0.90s
#        381           0.4871            0.89s
#        382           0.4870            0.89s
#        383           0.4869            0.89s
#        384           0.4868            0.89s
#        385           0.4867            0.89s
#        386           0.4866            0.89s
#        387           0.4863            0.89s
#        388           0.4861            0.88s
#        389           0.4860            0.88s
#        390           0.4857            0.88s
#        391           0.4855            0.88s
#        392           0.4852            0.88s
#        393           0.4850            0.88s
#        394           0.4848            0.88s
#        395           0.4848            0.87s
#        396           0.4844            0.87s
#        397           0.4842            0.87s
#        398           0.4839            0.87s
#        399           0.4839            0.87s
#        400           0.4838            0.87s
#        401           0.4837            0.87s
#        402           0.4836            0.86s
#        403           0.4833            0.86s
#        404           0.4830            0.86s
#        405           0.4829            0.86s
#        406           0.4827            0.86s
#        407           0.4826            0.86s
#        408           0.4824            0.85s
#        409           0.4822            0.85s
#        410           0.4819            0.85s
#        411           0.4817            0.85s
#        412           0.4815            0.85s
#        413           0.4814            0.85s
#        414           0.4813            0.85s
#        415           0.4811            0.85s
#        416           0.4809            0.85s
#        417           0.4809            0.84s
#        418           0.4806            0.84s
#        419           0.4805            0.84s
#        420           0.4803            0.84s
#        421           0.4802            0.84s
#        422           0.4801            0.84s
#        423           0.4801            0.84s
#        424           0.4799            0.84s
#        425           0.4798            0.84s
#        426           0.4797            0.83s
#        427           0.4796            0.83s
#        428           0.4795            0.83s
#        429           0.4794            0.83s
#        430           0.4794            0.83s
#        431           0.4793            0.83s
#        432           0.4792            0.83s
#        433           0.4792            0.82s
#        434           0.4789            0.82s
#        435           0.4787            0.82s
#        436           0.4786            0.82s
#        437           0.4785            0.82s
#        438           0.4784            0.82s
#        439           0.4783            0.82s
#        440           0.4782            0.82s
#        441           0.4779            0.82s
#        442           0.4778            0.81s
#        443           0.4777            0.81s
#        444           0.4775            0.81s
#        445           0.4773            0.81s
#        446           0.4772            0.81s
#        447           0.4770            0.81s
#        448           0.4769            0.81s
#        449           0.4768            0.81s
#        450           0.4766            0.81s
#        451           0.4766            0.80s
#        452           0.4764            0.80s
#        453           0.4763            0.80s
#        454           0.4762            0.80s
#        455           0.4762            0.80s
#        456           0.4759            0.80s
#        457           0.4757            0.80s
#        458           0.4756            0.79s
#        459           0.4755            0.79s
#        460           0.4754            0.79s
#        461           0.4752            0.79s
#        462           0.4751            0.79s
#        463           0.4750            0.79s
#        464           0.4750            0.79s
#        465           0.4749            0.79s
#        466           0.4749            0.78s
#        467           0.4747            0.78s
#        468           0.4746            0.78s
#        469           0.4739            0.78s
#        470           0.4738            0.78s
#        471           0.4735            0.78s
#        472           0.4734            0.78s
#        473           0.4733            0.77s
#        474           0.4732            0.77s
#        475           0.4732            0.77s
#        476           0.4730            0.77s
#        477           0.4729            0.77s
#        478           0.4729            0.77s
#        479           0.4728            0.77s
#        480           0.4726            0.77s
#        481           0.4726            0.76s
#        482           0.4726            0.76s
#        483           0.4725            0.76s
#        484           0.4725            0.76s
#        485           0.4724            0.76s
#        486           0.4723            0.76s
#        487           0.4722            0.76s
#        488           0.4720            0.75s
#        489           0.4719            0.75s
#        490           0.4717            0.75s
#        491           0.4716            0.75s
#        492           0.4714            0.75s
#        493           0.4713            0.75s
#        494           0.4711            0.75s
#        495           0.4709            0.75s
#        496           0.4707            0.75s
#        497           0.4706            0.74s
#        498           0.4706            0.74s
#        499           0.4705            0.74s
#        500           0.4704            0.74s
#        501           0.4703            0.74s
#        502           0.4701            0.74s
#        503           0.4699            0.74s
#        504           0.4698            0.74s
#        505           0.4696            0.74s
#        506           0.4695            0.73s
#        507           0.4694            0.73s
#        508           0.4692            0.73s
#        509           0.4692            0.73s
#        510           0.4691            0.73s
#        511           0.4690            0.73s
#        512           0.4689            0.73s
#        513           0.4689            0.72s
#        514           0.4688            0.72s
#        515           0.4687            0.72s
#        516           0.4686            0.72s
#        517           0.4685            0.72s
#        518           0.4684            0.72s
#        519           0.4682            0.72s
#        520           0.4681            0.71s
#        521           0.4679            0.71s
#        522           0.4677            0.71s
#        523           0.4676            0.71s
#        524           0.4676            0.71s
#        525           0.4675            0.71s
#        526           0.4674            0.71s
#        527           0.4673            0.71s
#        528           0.4673            0.70s
#        529           0.4672            0.70s
#        530           0.4671            0.70s
#        531           0.4671            0.70s
#        532           0.4670            0.70s
#        533           0.4669            0.70s
#        534           0.4668            0.70s
#        535           0.4668            0.69s
#        536           0.4667            0.69s
#        537           0.4666            0.69s
#        538           0.4666            0.69s
#        539           0.4665            0.69s
#        540           0.4664            0.69s
#        541           0.4663            0.69s
#        542           0.4662            0.68s
#        543           0.4661            0.68s
#        544           0.4661            0.68s
#        545           0.4659            0.68s
#        546           0.4658            0.68s
#        547           0.4657            0.68s
#        548           0.4656            0.68s
#        549           0.4656            0.67s
#        550           0.4654            0.67s
#        551           0.4653            0.67s
#        552           0.4651            0.67s
#        553           0.4650            0.67s
#        554           0.4649            0.67s
#        555           0.4648            0.67s
#        556           0.4648            0.67s
#        557           0.4647            0.66s
#        558           0.4646            0.66s
#        559           0.4645            0.66s
#        560           0.4644            0.66s
#        561           0.4644            0.66s
#        562           0.4644            0.66s
#        563           0.4644            0.66s
#        564           0.4642            0.65s
#        565           0.4641            0.65s
#        566           0.4639            0.65s
#        567           0.4638            0.65s
#        568           0.4637            0.65s
#        569           0.4636            0.65s
#        570           0.4635            0.65s
#        571           0.4635            0.65s
#        572           0.4634            0.64s
#        573           0.4634            0.64s
#        574           0.4633            0.64s
#        575           0.4632            0.64s
#        576           0.4632            0.64s
#        577           0.4631            0.64s
#        578           0.4629            0.64s
#        579           0.4629            0.63s
#        580           0.4628            0.63s
#        581           0.4625            0.63s
#        582           0.4624            0.63s
#        583           0.4623            0.63s
#        584           0.4622            0.63s
#        585           0.4621            0.63s
#        586           0.4621            0.63s
#        587           0.4620            0.62s
#        588           0.4618            0.62s
#        589           0.4618            0.62s
#        590           0.4617            0.62s
#        591           0.4616            0.62s
#        592           0.4615            0.62s
#        593           0.4614            0.62s
#        594           0.4613            0.61s
#        595           0.4612            0.61s
#        596           0.4611            0.61s
#        597           0.4610            0.61s
#        598           0.4609            0.61s
#        599           0.4607            0.61s
#        600           0.4607            0.61s
#        601           0.4606            0.60s
#        602           0.4605            0.60s
#        603           0.4605            0.60s
#        604           0.4604            0.60s
#        605           0.4603            0.60s
#        606           0.4602            0.60s
#        607           0.4602            0.60s
#        608           0.4600            0.59s
#        609           0.4600            0.59s
#        610           0.4600            0.59s
#        611           0.4600            0.59s
#        612           0.4599            0.59s
#        613           0.4598            0.59s
#        614           0.4597            0.59s
#        615           0.4597            0.58s
#        616           0.4596            0.58s
#        617           0.4596            0.58s
#        618           0.4594            0.58s
#        619           0.4592            0.58s
#        620           0.4592            0.58s
#        621           0.4591            0.58s
#        622           0.4591            0.57s
#        623           0.4591            0.57s
#        624           0.4591            0.57s
#        625           0.4590            0.57s
#        626           0.4589            0.57s
#        627           0.4588            0.57s
#        628           0.4588            0.57s
#        629           0.4587            0.56s
#        630           0.4587            0.56s
#        631           0.4586            0.56s
#        632           0.4586            0.56s
#        633           0.4586            0.56s
#        634           0.4585            0.56s
#        635           0.4585            0.55s
#        636           0.4584            0.55s
#        637           0.4583            0.55s
#        638           0.4582            0.55s
#        639           0.4581            0.55s
#        640           0.4581            0.55s
#        641           0.4580            0.55s
#        642           0.4579            0.54s
#        643           0.4579            0.54s
#        644           0.4578            0.54s
#        645           0.4578            0.54s
#        646           0.4577            0.54s
#        647           0.4576            0.54s
#        648           0.4575            0.54s
#        649           0.4574            0.53s
#        650           0.4573            0.53s
#        651           0.4572            0.53s
#        652           0.4571            0.53s
#        653           0.4571            0.53s
#        654           0.4570            0.53s
#        655           0.4569            0.53s
#        656           0.4568            0.52s
#        657           0.4567            0.52s
#        658           0.4566            0.52s
#        659           0.4566            0.52s
#        660           0.4565            0.52s
#        661           0.4564            0.52s
#        662           0.4564            0.52s
#        663           0.4561            0.51s
#        664           0.4560            0.51s
#        665           0.4559            0.51s
#        666           0.4558            0.51s
#        667           0.4558            0.51s
#        668           0.4557            0.51s
#        669           0.4557            0.51s
#        670           0.4556            0.50s
#        671           0.4556            0.50s
#        672           0.4555            0.50s
#        673           0.4555            0.50s
#        674           0.4555            0.50s
#        675           0.4554            0.50s
#        676           0.4554            0.50s
#        677           0.4554            0.49s
#        678           0.4553            0.49s
#        679           0.4551            0.49s
#        680           0.4551            0.49s
#        681           0.4550            0.49s
#        682           0.4549            0.49s
#        683           0.4549            0.48s
#        684           0.4548            0.48s
#        685           0.4548            0.48s
#        686           0.4547            0.48s
#        687           0.4546            0.48s
#        688           0.4545            0.48s
#        689           0.4544            0.48s
#        690           0.4544            0.47s
#        691           0.4543            0.47s
#        692           0.4543            0.47s
#        693           0.4543            0.47s
#        694           0.4542            0.47s
#        695           0.4541            0.47s
#        696           0.4540            0.47s
#        697           0.4539            0.46s
#        698           0.4539            0.46s
#        699           0.4539            0.46s
#        700           0.4539            0.46s
#        701           0.4538            0.46s
#        702           0.4538            0.46s
#        703           0.4537            0.45s
#        704           0.4536            0.45s
#        705           0.4536            0.45s
#        706           0.4535            0.45s
#        707           0.4535            0.45s
#        708           0.4535            0.45s
#        709           0.4535            0.45s
#        710           0.4534            0.44s
#        711           0.4534            0.44s
#        712           0.4533            0.44s
#        713           0.4532            0.44s
#        714           0.4532            0.44s
#        715           0.4531            0.44s
#        716           0.4531            0.44s
#        717           0.4531            0.43s
#        718           0.4531            0.43s
#        719           0.4529            0.43s
#        720           0.4529            0.43s
#        721           0.4528            0.43s
#        722           0.4528            0.43s
#        723           0.4527            0.42s
#        724           0.4526            0.42s
#        725           0.4526            0.42s
#        726           0.4526            0.42s
#        727           0.4525            0.42s
#        728           0.4525            0.42s
#        729           0.4524            0.42s
#        730           0.4519            0.41s
#        731           0.4519            0.41s
#        732           0.4519            0.41s
#        733           0.4518            0.41s
#        734           0.4517            0.41s
#        735           0.4516            0.41s
#        736           0.4516            0.40s
#        737           0.4515            0.40s
#        738           0.4515            0.40s
#        739           0.4514            0.40s
#        740           0.4513            0.40s
#        741           0.4513            0.40s
#        742           0.4512            0.40s
#        743           0.4511            0.39s
#        744           0.4511            0.39s
#        745           0.4510            0.39s
#        746           0.4509            0.39s
#        747           0.4508            0.39s
#        748           0.4508            0.39s
#        749           0.4508            0.39s
#        750           0.4507            0.38s
#        751           0.4507            0.38s
#        752           0.4506            0.38s
#        753           0.4506            0.38s
#        754           0.4506            0.38s
#        755           0.4506            0.38s
#        756           0.4505            0.38s
#        757           0.4505            0.37s
#        758           0.4504            0.37s
#        759           0.4503            0.37s
#        760           0.4502            0.37s
#        761           0.4502            0.37s
#        762           0.4502            0.37s
#        763           0.4502            0.36s
#        764           0.4501            0.36s
#        765           0.4501            0.36s
#        766           0.4500            0.36s
#        767           0.4500            0.36s
#        768           0.4500            0.36s
#        769           0.4499            0.36s
#        770           0.4499            0.35s
#        771           0.4498            0.35s
#        772           0.4497            0.35s
#        773           0.4496            0.35s
#        774           0.4496            0.35s
#        775           0.4495            0.35s
#        776           0.4494            0.35s
#        777           0.4493            0.34s
#        778           0.4493            0.34s
#        779           0.4493            0.34s
#        780           0.4492            0.34s
#        781           0.4492            0.34s
#        782           0.4491            0.34s
#        783           0.4491            0.33s
#        784           0.4490            0.33s
#        785           0.4490            0.33s
#        786           0.4490            0.33s
#        787           0.4489            0.33s
#        788           0.4489            0.33s
#        789           0.4489            0.33s
#        790           0.4488            0.32s
#        791           0.4487            0.32s
#        792           0.4487            0.32s
#        793           0.4487            0.32s
#        794           0.4486            0.32s
#        795           0.4485            0.32s
#        796           0.4485            0.32s
#        797           0.4484            0.31s
#        798           0.4484            0.31s
#        799           0.4484            0.31s
#        800           0.4483            0.31s
#        801           0.4483            0.31s
#        802           0.4483            0.31s
#        803           0.4482            0.30s
#        804           0.4482            0.30s
#        805           0.4481            0.30s
#        806           0.4481            0.30s
#        807           0.4480            0.30s
#        808           0.4480            0.30s
#        809           0.4479            0.30s
#        810           0.4479            0.29s
#        811           0.4479            0.29s
#        812           0.4478            0.29s
#        813           0.4477            0.29s
#        814           0.4477            0.29s
#        815           0.4476            0.29s
#        816           0.4475            0.28s
#        817           0.4474            0.28s
#        818           0.4474            0.28s
#        819           0.4473            0.28s
#        820           0.4473            0.28s
#        821           0.4473            0.28s
#        822           0.4473            0.28s
#        823           0.4473            0.27s
#        824           0.4472            0.27s
#        825           0.4472            0.27s
#        826           0.4471            0.27s
#        827           0.4471            0.27s
#        828           0.4471            0.27s
#        829           0.4471            0.26s
#        830           0.4470            0.26s
#        831           0.4470            0.26s
#        832           0.4469            0.26s
#        833           0.4468            0.26s
#        834           0.4467            0.26s
#        835           0.4467            0.26s
#        836           0.4466            0.25s
#        837           0.4465            0.25s
#        838           0.4465            0.25s
#        839           0.4464            0.25s
#        840           0.4464            0.25s
#        841           0.4464            0.25s
#        842           0.4464            0.25s
#        843           0.4464            0.24s
#        844           0.4463            0.24s
#        845           0.4463            0.24s
#        846           0.4462            0.24s
#        847           0.4462            0.24s
#        848           0.4461            0.24s
#        849           0.4461            0.23s
#        850           0.4461            0.23s
#        851           0.4460            0.23s
#        852           0.4460            0.23s
#        853           0.4460            0.23s
#        854           0.4459            0.23s
#        855           0.4459            0.23s
#        856           0.4459            0.22s
#        857           0.4458            0.22s
#        858           0.4458            0.22s
#        859           0.4457            0.22s
#        860           0.4456            0.22s
#        861           0.4456            0.22s
#        862           0.4455            0.21s
#        863           0.4454            0.21s
#        864           0.4453            0.21s
#        865           0.4452            0.21s
#        866           0.4452            0.21s
#        867           0.4452            0.21s
#        868           0.4451            0.21s
#        869           0.4451            0.20s
#        870           0.4450            0.20s
#        871           0.4450            0.20s
#        872           0.4450            0.20s
#        873           0.4449            0.20s
#        874           0.4449            0.20s
#        875           0.4449            0.19s
#        876           0.4449            0.19s
#        877           0.4448            0.19s
#        878           0.4448            0.19s
#        879           0.4448            0.19s
#        880           0.4447            0.19s
#        881           0.4447            0.18s
#        882           0.4447            0.18s
#        883           0.4447            0.18s
#        884           0.4447            0.18s
#        885           0.4446            0.18s
#        886           0.4446            0.18s
#        887           0.4445            0.18s
#        888           0.4445            0.17s
#        889           0.4445            0.17s
#        890           0.4444            0.17s
#        891           0.4443            0.17s
#        892           0.4443            0.17s
#        893           0.4443            0.17s
#        894           0.4442            0.16s
#        895           0.4441            0.16s
#        896           0.4441            0.16s
#        897           0.4440            0.16s
#        898           0.4440            0.16s
#        899           0.4439            0.16s
#        900           0.4439            0.16s
#        901           0.4438            0.15s
#        902           0.4438            0.15s
#        903           0.4437            0.15s
#        904           0.4437            0.15s
#        905           0.4436            0.15s
#        906           0.4436            0.15s
#        907           0.4436            0.14s
#        908           0.4435            0.14s
#        909           0.4435            0.14s
#        910           0.4434            0.14s
#        911           0.4434            0.14s
#        912           0.4434            0.14s
#        913           0.4434            0.13s
#        914           0.4434            0.13s
#        915           0.4433            0.13s
#        916           0.4433            0.13s
#        917           0.4433            0.13s
#        918           0.4433            0.13s
#        919           0.4432            0.13s
#        920           0.4432            0.12s
#        921           0.4432            0.12s
#        922           0.4432            0.12s
#        923           0.4431            0.12s
#        924           0.4430            0.12s
#        925           0.4430            0.12s
#        926           0.4430            0.11s
#        927           0.4429            0.11s
#        928           0.4429            0.11s
#        929           0.4429            0.11s
#        930           0.4429            0.11s
#        931           0.4428            0.11s
#        932           0.4428            0.11s
#        933           0.4427            0.10s
#        934           0.4419            0.10s
#        935           0.4419            0.10s
#        936           0.4419            0.10s
#        937           0.4418            0.10s
#        938           0.4418            0.10s
#        939           0.4418            0.09s
#        940           0.4417            0.09s
#        941           0.4417            0.09s
#        942           0.4416            0.09s
#        943           0.4416            0.09s
#        944           0.4415            0.09s
#        945           0.4415            0.08s
#        946           0.4415            0.08s
#        947           0.4415            0.08s
#        948           0.4414            0.08s
#        949           0.4414            0.08s
#        950           0.4413            0.08s
#        951           0.4413            0.08s
#        952           0.4412            0.07s
#        953           0.4412            0.07s
#        954           0.4412            0.07s
#        955           0.4411            0.07s
#        956           0.4411            0.07s
#        957           0.4411            0.07s
#        958           0.4411            0.06s
#        959           0.4410            0.06s
#        960           0.4410            0.06s
#        961           0.4409            0.06s
#        962           0.4409            0.06s
#        963           0.4409            0.06s
#        964           0.4409            0.06s
#        965           0.4408            0.05s
#        966           0.4408            0.05s
#        967           0.4408            0.05s
#        968           0.4408            0.05s
#        969           0.4408            0.05s
#        970           0.4408            0.05s
#        971           0.4407            0.04s
#        972           0.4407            0.04s
#        973           0.4407            0.04s
#        974           0.4406            0.04s
#        975           0.4406            0.04s
#        976           0.4405            0.04s
#        977           0.4405            0.04s
#        978           0.4404            0.03s
#        979           0.4403            0.03s
#        980           0.4403            0.03s
#        981           0.4403            0.03s
#        982           0.4402            0.03s
#        983           0.4402            0.03s
#        984           0.4402            0.02s
#        985           0.4401            0.02s
#        986           0.4401            0.02s
#        987           0.4401            0.02s
#        988           0.4400            0.02s
#        989           0.4399            0.02s
#        990           0.4399            0.02s
#        991           0.4399            0.01s
#        992           0.4399            0.01s
#        993           0.4398            0.01s
#        994           0.4398            0.01s
#        995           0.4397            0.01s
#        996           0.4397            0.01s
#        997           0.4397            0.00s
#        998           0.4396            0.00s
#        999           0.4395            0.00s
#       1000           0.4395            0.00s

# %%
# Fit random forest to basic model (sub_grade only)
rfc_b = RandomForestClassifier()
rfc_b.fit(X_train_under,y_train_under)
predicted_b = rfc_b.predict(X_val_under)
# Out:
# /Users/randy/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)

# %%
def find_best_threshold(model, int_num_steps):
    highest_f1 = 0
    best_threshold = 0
    for threshold in np.linspace (0, 1, int_num_steps):
        y_predict = (model.predict_proba(X_val_under)[:, 1] >= threshold) 
        f1 = f1_score(y_val_under,y_predict)
        if f1 > highest_f1:
            best_threshold, highest_f1 = threshold, f1
    return best_threshold, highest_f1

# %%
best_thresh, high_f1 = find_best_threshold(rfc,20)
print('Best Threshold: ', best_thresh)
print('Highest_f1: ', high_f1)
# Out:
# Best Threshold:  0.3157894736842105
# Highest_f1:  0.8516516516516517

# %%
# Examine the correlation of the model errors

knn_error = y_train_under - knn_grid.predict_proba(X_train_under)[:,1]
logit_error = y_train_under - logistic_grid.predict_proba(X_train_under)[:,1]
svm_error = y_train_under - svm_grid.predict_proba(X_train_under)[:,1]
gnb_error = y_train_under - gnb_best.predict_proba(X_train_under)[:,1]
rf_error = y_train_under - CV_rfc.predict_proba(X_train_under)[:,1]

error_df = pd.DataFrame()
error_df['knn'] = knn_error
error_df['logit'] = logit_error
error_df['svm'] = svm_error
error_df['gnb'] = gnb_error
error_df['rand_forest'] = rf_error

error_df.corr()
# Out:
#              knn  logit  svm  gnb  rand_forest
# knn         1.00   0.70 0.83 0.60         0.92
# logit       0.70   1.00 0.66 0.90         0.78
# svm         0.83   0.66 1.00 0.49         0.89
# gnb         0.60   0.90 0.49 1.00         0.70
# rand_forest 0.92   0.78 0.89 0.70         1.00

# %%
y_true = np.array([0, 0, 1, 1])
y_scores = np.array([0.1, 0.4, 0.35, 0.8])
precision, recall, thresholds = precision_recall_curve(y_true, y_scores)

# %%
features = []
for item in X_train.columns:
    features.append(item)

# %%
clf = tree.DecisionTreeClassifier(criterion="gini", max_depth=3)
clf = clf.fit(X_train_under, y_train_under)

dot_data = tree.export_graphviz(clf, out_file=None) 
graph = graphviz.Source(dot_data) 
graph.render("Fraud") 

dot_data = tree.export_graphviz(clf, out_file=None, 
                      feature_names=features,  
                      class_names=['NotFraud','isFraud'], 
                      filled=True, rounded=True,  
                      special_characters=True)  
graph = graphviz.Source(dot_data)  
graph

# %% [markdown]
# ## Log Loss Cross-Entropy
#
# _A more intensive metric for measuring the performance of your models._ So far, everything we've discussed uses "hard-predictions" to determine how well the model is doing. You apply some threshold and decided, "yes, I believe this is class XYZ" before checking to see if it's actually XYZ.
#
# That's an okay method, but it doesn't really give us a sense of how close the model was to being wrong. E.g., if we have a threshold of `0.5` and a record that's actually class 1, precision, recall, accuracy, etc. all give equal credit to a prediction that got the class correct, whether it was with `p = 0.51` or `p=0.99`. The second is much higher confidence though!
#
# Similarly, they give equal penalty to `p = 0.49` and `p=0.01`, though we were much more confident (in the wrong direction) in the second case. Guesses around `0.5` shouldn't be penalized as much, because our model is already admitting "hey, I don't really know what this observation is."
#
# Enter log-loss. For the binary case, we can define log-loss:
#
# $$ LLCE = - \sum_{i=1}^{N} y \cdot log(p_{y}) + (1-y) \cdot log((1-p_{y}))$$
#
# What does this do? It says, "If the class is actually 1, did you predict close to p=1? If not, that's a big penalty. Though, we'll penalize you way more if you predicted close to p=0. If the class is actually 0, did you predict close to p=0? If not, that's another big penalty."
#
# The main take-aways here are:
#
# >- Log-loss allows us to measure not just "did our model get XYZ right?" but "how confident was it in when predicting?"
# >
# >- A lower log-loss is better
#
# The cost function typically used for Gradient Descent on classification is log-loss-cross-entropy!

# %% [markdown]
# # Plotly

# %%
# load packages
import sklearn
import plotly.plotly as py
import plotly.graph_objs as go
from plotly import tools

import numpy as np
import matplotlib.pyplot as plt
from sklearn import svm, datasets

# %%
# import some data to play with
X = X_train_under  # we only take the first two features. We could
                      # avoid this ugly slicing by using a two-dim dataset
y = y_train_under

h = .02  # step size in the mesh

# we create an instance of SVM and fit out data. We do not scale our
# data since we want to plot the support vectors
C = 1.0  # SVM regularization parameter
svc = svm.SVC(kernel='linear', verbose=30, gamma='auto' C=C).fit(X, y)
rbf_svc = svm.SVC(kernel='rbf',verbose=30, gamma=0.7, C=C).fit(X, y)
poly_svc = svm.SVC(kernel='poly',verbose=30, degree=3, C=C).fit(X, y)
lin_svc = svm.LinearSVC(verbose=30,C=C).fit(X, y)

# create a mesh to plot in
x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
x_ = np.arange(x_min, x_max) #,h
y_ = np.arange(y_min, y_max) #,h
xx, yy = np.meshgrid(x_, y_)

# title for the plots
titles = ('SVC with linear kernel',
          'LinearSVC (linear kernel)',
          'SVC with RBF kernel',
          'SVC with polynomial (degree 3) kernel')
# Out:
#   File "<ipython-input-64-439889fc018a>", line 11
#     svc = svm.SVC(kernel='linear', verbose=30, gamma='auto' C=C).fit(X, y)
#                                                             ^
# SyntaxError: invalid syntax

# %%
def matplotlib_to_plotly(cmap, pl_entries):
    h = 1.0/(pl_entries-1)
    pl_colorscale = []
    
    for k in range(pl_entries):
        C = map(np.uint8, np.array(cmap(k*h)[:3])*255)
        pl_colorscale.append([k*h, 'rgb'+str((C[0], C[1], C[2]))])
        
    return pl_colorscale

cmap = matplotlib_to_plotly(plt.cm.coolwarm, 5)

fig = tools.make_subplots(rows=2, cols=2,
                          print_grid=False,
                          subplot_titles=titles)

# %%
for i, clf in enumerate((svc, lin_svc, rbf_svc, poly_svc)):
    # Plot the decision boundary. For that, we will assign a color to each
    # point in the mesh [x_min, x_max]x[y_min, y_max].
    Z = clf.predict(np.c_[xx.ravel(), yy.ravel()])

    # Put the result into a color plot
    Z = Z.reshape(xx.shape)
    p1 = go.Contour(x=x_, y=y_, z=Z, 
                    colorscale=cmap,
                    showscale=False)
    fig.append_trace(p1, i/2+1, i%2+1)

    # Plot also the training points
    p2 = go.Scatter(x=X[:, 0], y=X[:, 1], 
                    mode='markers',
                    marker=dict(color=y,
                                colorscale=cmap,
                                showscale=False,
                                line=dict(color='black', width=1))
                   )   
    fig.append_trace(p2, i/2+1, i%2+1)

# %%
for i in map(str, range(1, 5)):
    y = 'yaxis'+ i
    x = 'xaxis'+i
    fig['layout'][y].update(showticklabels=False, ticks='',
                            title="Sepal Length")
    fig['layout'][x].update(showticklabels=False, ticks='',
                            title="Sepal Width")

fig['layout'].update(height=700, showlegend=False)

py.iplot(fig)
